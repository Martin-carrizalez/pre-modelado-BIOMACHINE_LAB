# %%
"""
NOTEBOOK 02.5: TRADUCCIÓN DE NOMBRES DE COLUMNAS A ESPAÑOL
===========================================================

Objetivo: Renombrar columnas a español para análisis más profesional
"""

import pandas as pd

print("="*80)
print("🔄 TRADUCCIÓN DE NOMBRES DE COLUMNAS A ESPAÑOL")
print("="*80)

# ================================================================
# PASO 1: Cargar dataset y ver columnas actuales
# ================================================================

df = pd.read_csv('PCOS_data_winsorized.csv')
# Limpiar espacios en nombres de columnas
df.columns = df.columns.str.strip()  # Quita espacios al inicio/final
df.columns = df.columns.str.replace(r'\s+', ' ', regex=True)  # Normaliza espacios internos

print(f"\n📊 Dataset original:")
print(f"   Filas: {len(df)}")
print(f"   Columnas: {len(df.columns)}")

print(f"\n📝 COLUMNAS ACTUALES (INGLÉS):")
for i, col in enumerate(df.columns, 1):
    print(f"   {i:2}. '{col}'")

# ================================================================
# PASO 2: Diccionario de traducción
# ================================================================

print("\n" + "="*80)
print("🔄 APLICANDO TRADUCCIÓN")
print("="*80)

# Diccionario completo de traducción
translation = {
    # Variable objetivo
    'PCOS (Y/N)': 'SOP (S/N)',
    
    # Demográficas
    'Age (yrs)': 'Edad (años)',
    ' Age (yrs)': 'Edad (años)',  # Por si tiene espacio
    'Weight (Kg)': 'Peso (Kg)',
    'Height(Cm)': 'Altura (cm)',
    'Height(Cm) ': 'Altura (cm)',  # Por si tiene espacio
    'BMI': 'IMC',
    'Blood Group': 'Grupo Sanguíneo',
    'Marraige Status (Yrs)': 'Años Casada',
    
    # Signos vitales
    'Pulse rate(bpm)': 'Frecuencia Cardiaca (lpm)',
    'Pulse rate(bpm) ': 'Frecuencia Cardiaca (lpm)',
    'RR (breaths/min)': 'Frecuencia Respiratoria (rpm)',
    'Hb(g/dl)': 'Hemoglobina (g/dl)',
    'BP _Systolic (mmHg)': 'Presión Sistólica (mmHg)',
    'BP _Diastolic (mmHg)': 'Presión Diastólica (mmHg)',
    
    # Ciclo menstrual
    'Cycle(R/I)': 'Ciclo (R/I)',
    'Cycle length(days)': 'Duración Ciclo (días)',
    'Pregnant(Y/N)': 'Embarazada (S/N)',
    'No. of abortions': 'Número Abortos',
    
    # Hormonas
    'FSH(mIU/mL)': 'FSH (mUI/mL)',
    'LH(mIU/mL)': 'LH (mUI/mL)',
    'FSH/LH': 'Ratio FSH/LH',
    'TSH (mIU/L)': 'TSH (mUI/L)',
    'AMH(ng/mL)': 'AMH (ng/mL)',
    'PRL(ng/mL)': 'Prolactina (ng/mL)',
    'PRG(ng/mL)': 'Progesterona (ng/mL)',
    'II beta-HCG(mIU/mL)': 'beta-HCG II (mUI/mL)',
    'I beta-HCG(mIU/mL)': 'beta-HCG I (mUI/mL)',  # ← FALTA AGREGAR
    
    # Antropometría
    'Waist(inch)': 'Cintura (pulg)',
    'Hip(inch)': 'Cadera (pulg)',
    'Waist:Hip Ratio': 'Ratio Cintura-Cadera',
    
    # Síntomas
    'Weight gain(Y/N)': 'Aumento Peso (S/N)',
    'hair growth(Y/N)': 'Crecimiento Vello (S/N)',
    'Skin darkening (Y/N)': 'Oscurecimiento Piel (S/N)',
    'Hair loss(Y/N)': 'Pérdida Cabello (S/N)',
    'Pimples(Y/N)': 'Acné (S/N)',
    
    # Estilo de vida
    'Fast food (Y/N)': 'Comida Rápida (S/N)',
    'Reg.Exercise(Y/N)': 'Ejercicio Regular (S/N)',
    
    # Laboratorio
    'RBS(mg/dl)': 'Glucosa (mg/dl)',
    'Vit D3 (ng/mL)': 'Vitamina D3 (ng/mL)',
    
    # Ecografía
    'Follicle No. (L)': 'Num Folículos (I)',
    'Follicle No. (R)': 'Num Folículos (D)',
    'Avg. F size (L) (mm)': 'Tamaño Folículo Prom (I) (mm)',
    'Avg. F size (R) (mm)': 'Tamaño Folículo Prom (D) (mm)',
    'Endometrium (mm)': 'Endometrio (mm)'
}

# Aplicar traducción
df_spanish = df.rename(columns=translation)

print(f"\n✅ Traducción aplicada")
print(f"   Columnas renombradas: {len([k for k in translation.keys() if k in df.columns])}")

# ================================================================
# PASO 3: Verificar columnas traducidas
# ================================================================

print(f"\n📝 COLUMNAS NUEVAS (ESPAÑOL):")
for i, col in enumerate(df_spanish.columns, 1):
    # Marcar las que cambiaron
    original = df.columns[i-1]
    changed = "✅" if original != col else "  "
    print(f"   {changed} {i:2}. '{col}'")

# ================================================================
# PASO 4: Identificar columnas sin traducir
# ================================================================

print("\n" + "="*80)
print("⚠️ COLUMNAS SIN TRADUCIR (si las hay)")
print("="*80)

untranslated = []
for orig_col, new_col in zip(df.columns, df_spanish.columns):
    if orig_col == new_col and orig_col != 'SOP (S/N)':
        untranslated.append(orig_col)

if len(untranslated) > 0:
    print(f"\n⚠️ {len(untranslated)} columnas sin traducir:")
    for col in untranslated:
        print(f"   - '{col}'")
    print("\n💡 Agrega estas traducciones al diccionario si es necesario")
else:
    print("\n✅ Todas las columnas fueron traducidas")

# ================================================================
# PASO 5: Guardar dataset con nombres en español
# ================================================================

print("\n" + "="*80)
print("💾 GUARDANDO DATASET EN ESPAÑOL")
print("="*80)

# Guardar versión en español
df_spanish.to_csv('PCOS_data_espanol.csv', index=False)
print(f"\n✅ Dataset guardado: PCOS_data_espanol.csv")
print(f"   Filas: {len(df_spanish)}")
print(f"   Columnas: {len(df_spanish.columns)}")

# ================================================================
# PASO 6: Generar diccionario de mapeo para el código
# ================================================================

print("\n" + "="*80)
print("📋 DICCIONARIO DE MAPEO PARA CÓDIGO")
print("="*80)

print("\n# Usar este diccionario en el código de análisis:")
print("\nmapeo_columnas = {")
for orig, trans in translation.items():
    if orig in df.columns:
        print(f"    '{orig}': '{trans}',")
print("}")

# ================================================================
# PASO 7: Clasificación de variables en español
# ================================================================

print("\n" + "="*80)
print("📊 CLASIFICACIÓN DE VARIABLES (ESPAÑOL)")
print("="*80)

# Variables categóricas/binarias
categoricas_esp = [
    'Grupo Sanguíneo',
    'Ciclo (R/I)',
    'Embarazada (S/N)',
    'Aumento Peso (S/N)',
    'Crecimiento Vello (S/N)',
    'Oscurecimiento Piel (S/N)',
    'Pérdida Cabello (S/N)',
    'Acné (S/N)',
    'Comida Rápida (S/N)',
    'Ejercicio Regular (S/N)'
]

categoricas_esp = [col for col in categoricas_esp if col in df_spanish.columns]

# Variables count (discretas)
count_esp = [
    'Número Abortos',
    'Duración Ciclo (días)',
    'Años Casada',
    'Num Folículos (I)',
    'Num Folículos (D)'
]

count_esp = [col for col in count_esp if col in df_spanish.columns]

# Variables numéricas continuas
continuas_esp = [col for col in df_spanish.columns 
                 if col not in categoricas_esp 
                 and col not in count_esp 
                 and col != 'SOP (S/N)']

print(f"\n📊 RESUMEN:")
print(f"   Categóricas/Binarias: {len(categoricas_esp)}")
print(f"   Count (discretas): {len(count_esp)}")
print(f"   Continuas: {len(continuas_esp)}")
print(f"   TOTAL: {len(categoricas_esp) + len(count_esp) + len(continuas_esp)}")

print(f"\n📝 Variables categóricas:")
for var in categoricas_esp:
    print(f"   - {var}")

print(f"\n📝 Variables count:")
for var in count_esp:
    print(f"   - {var}")

print(f"\n📝 Variables continuas:")
for var in continuas_esp:
    print(f"   - {var}")

# Guardar clasificación
clasificacion = pd.DataFrame({
    'Variable': categoricas_esp + count_esp + continuas_esp,
    'Tipo': ['Categórica']*len(categoricas_esp) + ['Count']*len(count_esp) + ['Continua']*len(continuas_esp)
})

clasificacion.to_csv('clasificacion_variables_esp.csv', index=False)
print(f"\n💾 Clasificación guardada: clasificacion_variables_esp.csv")

print("\n" + "="*80)
print("✅ TRADUCCIÓN COMPLETADA")
print("="*80)
print("\n🎯 Siguiente paso: Ejecutar análisis estadístico con nombres en español")
print("   Usar: PCOS_data_espanol.csv")
# Out:
# ================================================================================
# 🔄 TRADUCCIÓN DE NOMBRES DE COLUMNAS A ESPAÑOL
# ================================================================================
#
# 📊 Dataset original:
#    Filas: 538
#    Columnas: 42
#
# 📝 COLUMNAS ACTUALES (INGLÉS):
#     1. 'PCOS (Y/N)'
#     2. 'Age (yrs)'
#     3. 'Weight (Kg)'
#     4. 'Height(Cm)'
#     5. 'BMI'
#     6. 'Blood Group'
#     7. 'Pulse rate(bpm)'
#     8. 'RR (breaths/min)'
#     9. 'Hb(g/dl)'
#    10. 'Cycle(R/I)'
#    11. 'Cycle length(days)'
#    12. 'Marraige Status (Yrs)'
#    13. 'Pregnant(Y/N)'
#    14. 'No. of abortions'
#    15. 'I beta-HCG(mIU/mL)'
#    16. 'II beta-HCG(mIU/mL)'
#    17. 'FSH(mIU/mL)'
#    18. 'LH(mIU/mL)'
#    19. 'FSH/LH'
#    20. 'Hip(inch)'
#    21. 'Waist(inch)'
#    22. 'Waist:Hip Ratio'
#    23. 'TSH (mIU/L)'
#    24. 'AMH(ng/mL)'
#    25. 'PRL(ng/mL)'
#    26. 'Vit D3 (ng/mL)'
#    27. 'PRG(ng/mL)'
#    28. 'RBS(mg/dl)'
#    29. 'Weight gain(Y/N)'
#    30. 'hair growth(Y/N)'
#    31. 'Skin darkening (Y/N)'
#    32. 'Hair loss(Y/N)'
#    33. 'Pimples(Y/N)'
#    34. 'Fast food (Y/N)'
#    35. 'Reg.Exercise(Y/N)'
#    36. 'BP _Systolic (mmHg)'
#    37. 'BP _Diastolic (mmHg)'
#    38. 'Follicle No. (L)'
#    39. 'Follicle No. (R)'
#    40. 'Avg. F size (L) (mm)'
#    41. 'Avg. F size (R) (mm)'
#    42. 'Endometrium (mm)'
#
# ================================================================================
# 🔄 APLICANDO TRADUCCIÓN
# ================================================================================
#
# ✅ Traducción aplicada
#    Columnas renombradas: 42
#
# 📝 COLUMNAS NUEVAS (ESPAÑOL):
#    ✅  1. 'SOP (S/N)'
#    ✅  2. 'Edad (años)'
#    ✅  3. 'Peso (Kg)'
#    ✅  4. 'Altura (cm)'
#    ✅  5. 'IMC'
#    ✅  6. 'Grupo Sanguíneo'
#    ✅  7. 'Frecuencia Cardiaca (lpm)'
#    ✅  8. 'Frecuencia Respiratoria (rpm)'
#    ✅  9. 'Hemoglobina (g/dl)'
#    ✅ 10. 'Ciclo (R/I)'
#    ✅ 11. 'Duración Ciclo (días)'
#    ✅ 12. 'Años Casada'
#    ✅ 13. 'Embarazada (S/N)'
#    ✅ 14. 'Número Abortos'
#    ✅ 15. 'beta-HCG I (mUI/mL)'
#    ✅ 16. 'beta-HCG II (mUI/mL)'
#    ✅ 17. 'FSH (mUI/mL)'
#    ✅ 18. 'LH (mUI/mL)'
#    ✅ 19. 'Ratio FSH/LH'
#    ✅ 20. 'Cadera (pulg)'
#    ✅ 21. 'Cintura (pulg)'
#    ✅ 22. 'Ratio Cintura-Cadera'
#    ✅ 23. 'TSH (mUI/L)'
#    ✅ 24. 'AMH (ng/mL)'
#    ✅ 25. 'Prolactina (ng/mL)'
#    ✅ 26. 'Vitamina D3 (ng/mL)'
#    ✅ 27. 'Progesterona (ng/mL)'
#    ✅ 28. 'Glucosa (mg/dl)'
#    ✅ 29. 'Aumento Peso (S/N)'
#    ✅ 30. 'Crecimiento Vello (S/N)'
#    ✅ 31. 'Oscurecimiento Piel (S/N)'
#    ✅ 32. 'Pérdida Cabello (S/N)'
#    ✅ 33. 'Acné (S/N)'
#    ✅ 34. 'Comida Rápida (S/N)'
#    ✅ 35. 'Ejercicio Regular (S/N)'
#    ✅ 36. 'Presión Sistólica (mmHg)'
#    ✅ 37. 'Presión Diastólica (mmHg)'
#    ✅ 38. 'Num Folículos (I)'
#    ✅ 39. 'Num Folículos (D)'
#    ✅ 40. 'Tamaño Folículo Prom (I) (mm)'
#    ✅ 41. 'Tamaño Folículo Prom (D) (mm)'
#    ✅ 42. 'Endometrio (mm)'
#
# ================================================================================
# ⚠️ COLUMNAS SIN TRADUCIR (si las hay)
# ================================================================================
#
# ✅ Todas las columnas fueron traducidas
#
# ================================================================================
# 💾 GUARDANDO DATASET EN ESPAÑOL
# ================================================================================
#
# ✅ Dataset guardado: PCOS_data_espanol.csv
#    Filas: 538
#    Columnas: 42
#
# ================================================================================
# 📋 DICCIONARIO DE MAPEO PARA CÓDIGO
# ================================================================================
#
# # Usar este diccionario en el código de análisis:
#
# mapeo_columnas = {
#     'PCOS (Y/N)': 'SOP (S/N)',
#     'Age (yrs)': 'Edad (años)',
#     'Weight (Kg)': 'Peso (Kg)',
#     'Height(Cm)': 'Altura (cm)',
#     'BMI': 'IMC',
#     'Blood Group': 'Grupo Sanguíneo',
#     'Marraige Status (Yrs)': 'Años Casada',
#     'Pulse rate(bpm)': 'Frecuencia Cardiaca (lpm)',
#     'RR (breaths/min)': 'Frecuencia Respiratoria (rpm)',
#     'Hb(g/dl)': 'Hemoglobina (g/dl)',
#     'BP _Systolic (mmHg)': 'Presión Sistólica (mmHg)',
#     'BP _Diastolic (mmHg)': 'Presión Diastólica (mmHg)',
#     'Cycle(R/I)': 'Ciclo (R/I)',
#     'Cycle length(days)': 'Duración Ciclo (días)',
#     'Pregnant(Y/N)': 'Embarazada (S/N)',
#     'No. of abortions': 'Número Abortos',
#     'FSH(mIU/mL)': 'FSH (mUI/mL)',
#     'LH(mIU/mL)': 'LH (mUI/mL)',
#     'FSH/LH': 'Ratio FSH/LH',
#     'TSH (mIU/L)': 'TSH (mUI/L)',
#     'AMH(ng/mL)': 'AMH (ng/mL)',
#     'PRL(ng/mL)': 'Prolactina (ng/mL)',
#     'PRG(ng/mL)': 'Progesterona (ng/mL)',
#     'II beta-HCG(mIU/mL)': 'beta-HCG II (mUI/mL)',
#     'I beta-HCG(mIU/mL)': 'beta-HCG I (mUI/mL)',
#     'Waist(inch)': 'Cintura (pulg)',
#     'Hip(inch)': 'Cadera (pulg)',
#     'Waist:Hip Ratio': 'Ratio Cintura-Cadera',
#     'Weight gain(Y/N)': 'Aumento Peso (S/N)',
#     'hair growth(Y/N)': 'Crecimiento Vello (S/N)',
#     'Skin darkening (Y/N)': 'Oscurecimiento Piel (S/N)',
#     'Hair loss(Y/N)': 'Pérdida Cabello (S/N)',
#     'Pimples(Y/N)': 'Acné (S/N)',
#     'Fast food (Y/N)': 'Comida Rápida (S/N)',
#     'Reg.Exercise(Y/N)': 'Ejercicio Regular (S/N)',
#     'RBS(mg/dl)': 'Glucosa (mg/dl)',
#     'Vit D3 (ng/mL)': 'Vitamina D3 (ng/mL)',
#     'Follicle No. (L)': 'Num Folículos (I)',
#     'Follicle No. (R)': 'Num Folículos (D)',
#     'Avg. F size (L) (mm)': 'Tamaño Folículo Prom (I) (mm)',
#     'Avg. F size (R) (mm)': 'Tamaño Folículo Prom (D) (mm)',
#     'Endometrium (mm)': 'Endometrio (mm)',
# }
#
# ================================================================================
# 📊 CLASIFICACIÓN DE VARIABLES (ESPAÑOL)
# ================================================================================
#
# 📊 RESUMEN:
#    Categóricas/Binarias: 10
#    Count (discretas): 5
#    Continuas: 26
#    TOTAL: 41
#
# 📝 Variables categóricas:
#    - Grupo Sanguíneo
#    - Ciclo (R/I)
#    - Embarazada (S/N)
#    - Aumento Peso (S/N)
#    - Crecimiento Vello (S/N)
#    - Oscurecimiento Piel (S/N)
#    - Pérdida Cabello (S/N)
#    - Acné (S/N)
#    - Comida Rápida (S/N)
#    - Ejercicio Regular (S/N)
#
# 📝 Variables count:
#    - Número Abortos
#    - Duración Ciclo (días)
#    - Años Casada
#    - Num Folículos (I)
#    - Num Folículos (D)
#
# 📝 Variables continuas:
#    - Edad (años)
#    - Peso (Kg)
#    - Altura (cm)
#    - IMC
#    - Frecuencia Cardiaca (lpm)
#    - Frecuencia Respiratoria (rpm)
#    - Hemoglobina (g/dl)
#    - beta-HCG I (mUI/mL)
#    - beta-HCG II (mUI/mL)
#    - FSH (mUI/mL)
#    - LH (mUI/mL)
#    - Ratio FSH/LH
#    - Cadera (pulg)
#    - Cintura (pulg)
#    - Ratio Cintura-Cadera
#    - TSH (mUI/L)
#    - AMH (ng/mL)
#    - Prolactina (ng/mL)
#    - Vitamina D3 (ng/mL)
#    - Progesterona (ng/mL)
#    - Glucosa (mg/dl)
#    - Presión Sistólica (mmHg)
#    - Presión Diastólica (mmHg)
#    - Tamaño Folículo Prom (I) (mm)
#    - Tamaño Folículo Prom (D) (mm)
#    - Endometrio (mm)
#
# 💾 Clasificación guardada: clasificacion_variables_esp.csv
#
# ================================================================================
# ✅ TRADUCCIÓN COMPLETADA
# ================================================================================
#
# 🎯 Siguiente paso: Ejecutar análisis estadístico con nombres en español
#    Usar: PCOS_data_espanol.csv
